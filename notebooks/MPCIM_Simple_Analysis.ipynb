# %% [markdown]
# # 🎓 MPCIM Thesis - Dual-Dimensional Predictive Analytics
#
# **Title**: Dual-Dimensional Predictive Analytics untuk Career Progression
# **Author**: Deni Sulaeman
# **Date**: November 2025
#
# ## 📋 Project Overview
#
# Predicting employee promotion using:
# 1. Performance Assessment
# 2. Behavioral Assessment
# 3. Psychological Assessment

# %% [markdown]
# ## 🔧 1. Setup & Installation

# %%
# Install required packages
# !pip install -q pandas numpy matplotlib seaborn plotly scikit-learn xgboost shap imbalanced-learn openpyxl
